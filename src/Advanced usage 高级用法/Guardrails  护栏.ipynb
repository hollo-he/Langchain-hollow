# %% [markdown]
# # Guardrails  护栏
# 防护机制通过在代理执行的关键节点验证和过滤内容，帮助构建安全合规的 AI 应用。它们可以检测敏感信息、强制执行内容策略、验证输出，并在不安全行为造成问题之前加以阻止
# - 防止个人身份信息泄露
# - 检测和阻止提示注入攻击
# - 屏蔽不当或有害内容
# - 执行业务规则和合规要求
# - 验证输出质量和准确性
#
# 内置: PII 检测 、 人机交互
# 自定义:前,后,组合
